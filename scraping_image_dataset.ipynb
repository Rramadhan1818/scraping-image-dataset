# %% [markdown]
# <a href="https://colab.research.google.com/github/Rramadhan1818/scraping-image-dataset/blob/master/scraping_image_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !mkdir dataset_openeyes

# %%
from bing_image_downloader import downloader

downloader.download('people close their eyes', limit=50, output_dir='dataset_images')
# Out:
# [%] Downloading Images to /content/dataset_images/people close their eyes
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 36 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.goodtherapy.org/blog/blog/wp-content/uploads/2013/02/Close-up-of-a-mans-eyes-shut-1024x790.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://media.istockphoto.com/photos/close-up-portrait-of-woman-with-eyes-closed-picture-id147206890?k=6&amp;m=147206890&amp;s=612x612&amp;w=0&amp;h=R-N4zISXrZSuRxgeeGXqBOavSKd25Q-6brKtkKOWIwo=
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.ghanaquest.com/wp-content/uploads/2019/08/why-people-close-eyes-while-kissing.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://pyxis.nymag.com/v1/imgs/b08/7b6/e805f481c1123e9ff1b8e8e7391138999e-16-closed-eyes.1x.rsocial.w1200.jpg
# ...

# %%
# !zip -r '/content/dataset_images.zip' '/content/dataset_images'
# Out:
#   adding: content/dataset_images/ (stored 0%)
#   adding: content/dataset_images/people open their eyes/ (stored 0%)
#   adding: content/dataset_images/people open their eyes/Image_43.jpg (deflated 0%)
#   adding: content/dataset_images/people open their eyes/Image_41.jpg (deflated 1%)
#   adding: content/dataset_images/people open their eyes/Image_50.jpg (deflated 2%)
#   adding: content/dataset_images/people open their eyes/Image_34.jpg (deflated 0%)
#   adding: content/dataset_images/people open their eyes/Image_22.jpg (deflated 4%)
#   adding: content/dataset_images/people open their eyes/Image_10.png (deflated 0%)
#   adding: content/dataset_images/people open their eyes/Image_26.jpg (deflated 0%)
#   adding: content/dataset_images/people open their eyes/Image_27.jpg (deflated 2%)
#   adding: content/dataset_images/people open their eyes/Image_29.jpg (deflated 5%)
#   adding: content/dataset_images/people open their eyes/Image_48.jpg (deflated 5%)
# ...
